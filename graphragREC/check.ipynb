# %%
import pandas as pd 
df=pd.read_csv('hairshop_recommend_dataset_realfinal_easy.csv')

# %%
# print(df.columns)
df.head()
df['final_dic_style'].value_counts().index
# df
# df.value_counts)
# df[['style','longitude','latitude','final_menu_price','review_count','mean_score']]
# Out:
# Index(['울프컷', '빌드펌', '아이비리그컷', '볼륨매직', '엘리자베스펌', '허그펌', '엘리자벳펌_레이어드컷',
#        '빌드펌_레이어드컷', '글램펌_레이어드컷', '숏컷', '쉐도우펌', '아이롱펌', '애즈펌', '슬릭애즈펌', '크롭컷',
#        '테슬펌', '테슬컷', '태슬펌_태슬컷', '투블럭컷', '허쉬펌', '허쉬컷', '허쉬펌_허쉬컷', '블럭컷',
#        '히피펌(젤리펌)', '빈티지펌_레이어드컷', '히피펌_샤기컷', '히피펌_레이어드컷', '바버컷', '히피펌', '리젠트컷',
#        '바디펌', 'S컬펌', 'S컬펌_레이어드컷', 'C컬펌_일자컷', '그레이스펌_레이어드컷', '프링펌', 'C컬펌_허쉬컷',
#        '허그펌_레이어드컷', 'C컬펌_레이어드컷', '샤밍컷', '그레이스펌', 'C컬펌', '레이어드컷', '가일컷',
#        '슬릭가일컷', '레이어드펌', '슬릭댄디컷', '시스루댄디컷', '다운펌', '구름펌_레이어드컷', '구름펌',
#        '매직스트레이트펌', '베베컷', '가일펌', '샤기컷', '리프컷', '포마드컷', '댄디펌', '뿌리볼륨펌', '발레아쥬',
#        '물결펌(플라워펌)', '스왓컷', '상고머리', '똑단발', '베이비펌', '매직셋팅', '페이지컷', '히메컷', '뱅헤어',
#        '셋팅펌', '웨이브펌', '웨이브펌_일자컷', '볼륨컷', '웨이브펌_레이어드컷', '슬릭백언더컷', '모히칸컷',
#        '샌드펌_레이어드컷', '샌드펌', '글래펌', '슬릭컷', '빈티지펌', '스핀스왈로펌', '장발', '슬릭펌', '디지털펌',
#        '하이라이트(위빙)', '리젠트펌', '웨딩스타일', '슬릭펌_슬릭컷'],
#       dtype='object', name='final_dic_style')

# %%
df.query('final_dic_style=="S컬펌_레이어드컷"')
# Out:
#     final_dic_style          hairshop style  mean_score  review_count  \
# 129       S컬펌_레이어드컷        그라벨르헤어 종로점   S컬펌    0.826667            15
# 134       S컬펌_레이어드컷       헤어아티스트M 대치점   S컬펌    0.825000             8
# 139       S컬펌_레이어드컷     준오헤어 가든강남구청역점   S컬펌    0.816667             6
# 144       S컬펌_레이어드컷           바이드 이대점   S컬펌    0.814286             7
# 149       S컬펌_레이어드컷         에이바헤어 강변점   S컬펌    0.810000            10
# 154       S컬펌_레이어드컷        리안헤어 강남일원점   S컬펌    0.807143            14
# 159       S컬펌_레이어드컷         코벨헤어 송파본점   S컬펌    0.805000            20
# 164       S컬펌_레이어드컷      준오헤어 남부터미널역점   S컬펌    0.800000             6
# 169       S컬펌_레이어드컷         H:ON HAIR   S컬펌    0.800000            20
# 174       S컬펌_레이어드컷           아르결 성수점   S컬펌    0.800000            16
# 179       S컬펌_레이어드컷  예민헤어살롱 송파역헬리오시티점   S컬펌    0.800000             8
# 184       S컬펌_레이어드컷         오슈아헤어 성수점   S컬펌    0.800000            29
# ...
